# %%
import eminipyparser.eminipyparser as ep
import os

# %%
input_str = """

letting vertices be domain int(1..3)
letting colours be domain int(1..3)
letting G be relation((1,2),(1,3),(2,3))
letting map be domain relation of (vertices * colours)
letting T be domain tuple (vertices,colours)
find C : map
find t : T
such that
  forAll (u,c) in C .
     forAll (v,d) in C .
        ((u = v) -> (c = d))
such that
  forAll u : vertices .
     exists c : colours . C(u,c)
such that
  forAll (u,v) in G .
     forAll c,d : colours . (C(u,c) /\ C(v,d) -> (c != d))
such that
  t in C
such that
  t[1] = t[2]

"""

# %%
parser = ep.EssenceParser(input_str)
statements = parser.parse()
rootTree = ep.Node("GraphColouring", statements)
ep.printTree(rootTree)
# Out:
# ['letting', 'vertices', 'be', 'domain', 'int', '(', '1', '..', '3', ')', 'letting', 'colours', 'be', 'domain', 'int', '(', '1', '..', '3', ')', 'letting', 'G', 'be', 'relation', '(', '(', '1', ',', '2', ')', ',', '(', '1', ',', '3', ')', ',', '(', '2', ',', '3', ')', ')', 'letting', 'map', 'be', 'domain', 'relation', 'of', '(', 'vertices', '*', 'colours', ')', 'letting', 'T', 'be', 'domain', 'tuple', '(', 'vertices', ',', 'colours', ')', 'find', 'C', ':', 'map', 'find', 't', ':', 'T', 'such', 'that', 'forAll', '(', 'u', ',', 'c', ')', 'in', 'C', '.', 'forAll', '(', 'v', ',', 'd', ')', 'in', 'C', '.', '(', '(', 'u', '=', 'v', ')', '->', '(', 'c', '=', 'd', ')', ')', 'such', 'that', 'forAll', 'u', ':', 'vertices', '.', 'exists', 'c', ':', 'colours', '.', 'C', '(', 'u', ',', 'c', ')', 'such', 'that', 'forAll', '(', 'u', ',', 'v', ')', 'in', 'G', '.', 'forAll', 'c', ',', 'd', ':', 'colours', '.', '(', 'C', '(', 'u', ',', 'c', ')', '/\\', 'C', '(', 'v', ',', 'd', ')', '->', '(', 'c', '!=', 'd', ')', ')', 'such', 'that', 't', 'in', 'C', 'such', 'that', 't', '[', '1', ']', '=', 't', '[', '2', ']']
# +- GraphColouring
#    +- letting
#    |  +- vertices
#    |     +- int
#    |        +- 1
#    |        +- 3
#    +- letting
#    |  +- colours
#    |     +- int
#    |        +- 1
#    |        +- 3
#    +- letting
#    |  +- G
#    |     +- relation
#    |        +- tuple
#    |        |  +- 1
#    |        |  +- 2
#    |        +- tuple
#    |        |  +- 1
#    |        |  +- 3
#    |        +- tuple
#    |           +- 2
#    |           +- 3
#    +- letting
#    |  +- map
#    |     +- relation
#    |        +- vertices
#    |        +- colours
#    +- letting
#    |  +- T
#    |     +- tuple
#    |        +- vertices
#    |        +- colours
#    +- find
#    |  +- C
#    |     +- map
#    +- find
#    |  +- t
#    |     +- T
#    +- such that
#    |  +-  .
#    |     +-  .
#    |     |  +- forAll
#    |     |  |  +- tuple
#    |     |  |  |  +- u
#    |     |  |  |  +- c
#    |     |  |  +- in
#    |     |  |     +- C
#    |     |  +- forAll
#    |     |     +- tuple
#    |     |     |  +- v
#    |     |     |  +- d
#    |     |     +- in
#    |     |        +- C
#    |     +- ->
#    |        +- =
#    |        |  +- u
#    |        |  +- v
#    |        +- =
#    |           +- c
#    |           +- d
#    +- such that
#    |  +-  .
#    |     +-  .
#    |     |  +- forAll
#    |     |  |  +- u
#    |     |  |  +- :
#    |     |  |     +- vertices
#    |     |  +- exists
#    |     |     +- c
#    |     |     +- :
#    |     |        +- colours
#    |     +- C
#    |        +- tuple
#    |           +- u
#    |           +- c
#    +- such that
#    |  +-  .
#    |     +-  .
#    |     |  +- forAll
#    |     |  |  +- tuple
#    |     |  |  |  +- u
#    |     |  |  |  +- v
#    |     |  |  +- in
#    |     |  |     +- G
#    |     |  +- forAll
#    |     |     +- c
#    |     |     +- d
#    |     |     +- :
#    |     |        +- colours
#    |     +- ->
#    |        +- /\
#    |        |  +- C
#    |        |  |  +- tuple
#    |        |  |     +- u
#    |        |  |     +- c
#    |        |  +- C
#    |        |     +- tuple
#    |        |        +- v
#    |        |        +- d
#    |        +- !=
#    |           +- c
#    |           +- d
#    +- such that
#    |  +- in
#    |     +- t
#    |     +- C
#    +- such that
#       +- =
#          +- t
#          |  +- 1
#          +- t
#             +- 2

# %%
a = ['1','2']
b = '3'
print([*a,b])
# Out:
# ['1', '2', '3']
